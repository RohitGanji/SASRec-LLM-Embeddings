# %%
import numpy as np
import pandas as pd

# %%
# user@rg-a100:~/repos/SASRec-LLM-Embeddings/python$ python main.py   --dataset=ml-1m   --train_dir=test_llm_zeroshot   --inference_only=true   --state_dict_path ml-1m_zeroshot_preLN/SASRec.epoch=860.lr=0.001.layer=2.head=1.hidden=50.maxlen=50.pth   --maxlen=50   --norm_first   --use_llm   --llm_emb_path artifacts/ml-1m/llm_item_emb.npy   --llm_dim 384
# average sequence length: 141.12
# load_state_dict strict=False
#   missing keys: ['llm_item_emb', 'cold_item_mask', 'llm_proj.weight']
#   unexpected keys: []
# ............................................................test (NDCG@10: 0.4317, HR@10: 0.6251)
# [cold dbg] user=5, gt_item=1570, rank=13
# [cold dbg] user=17, gt_item=490, rank=7
# [cold dbg] user=22, gt_item=732, rank=10
# [cold dbg] user=23, gt_item=3242, rank=7
# [cold dbg] user=26, gt_item=2843, rank=13
# cold_test k=0 (NDCG@10: 0.0607, HR@10: 0.1806, users: 1705)

# %%
ratings = pd.read_csv('python/raw_data/ml-1m/ratings.dat', sep='::', header=None)
movies = pd.read_csv('python/raw_data/ml-1m/movies.dat', sep='::', header=None)
# users = pd.read_csv('python/raw_data/ml-1m/users.dat', sep='::', header=None)
# Out:
# /tmp/ipykernel_75101/3844935014.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   ratings = pd.read_csv('python/raw_data/ml-1m/ratings.dat', sep='::', header=None)
# /tmp/ipykernel_75101/3844935014.py:2: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   movies = pd.read_csv('python/raw_data/ml-1m/movies.dat', sep='::', header=None)
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[21], line 2
#       1 ratings = pd.read_csv('python/raw_data/ml-1m/ratings.dat', sep='::', header=None)
# ...

# %%
users = pd.read_csv('python/raw_data/ml-1m/users.dat', sep='::', header=None)
# Out:
# /tmp/ipykernel_75101/3104619884.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   users = pd.read_csv('python/raw_data/ml-1m/users.dat', sep='::', header=None)
